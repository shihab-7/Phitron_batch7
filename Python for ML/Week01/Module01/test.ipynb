# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x=12 ; y=10; z=4
result = (x<y) and (y>z)

print(result)
# Out:
# False

# %% [markdown]
# problem digitsum

# %%
nums=input()

nums=nums.split()
x=int(nums[0])
y=int(nums[1])

lst_x=x%10
lst_y=y%10

ans=lst_x + lst_y

print(ans)
# Out:
# 3.5
